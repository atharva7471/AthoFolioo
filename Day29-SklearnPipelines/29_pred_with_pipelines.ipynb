# %% [markdown]
# <a href="https://colab.research.google.com/github/atharva7471/AthoFolioo/blob/main/Day29-SklearnPipelines/29_pred_with_pipelines.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pickle as pkl

# %%
pipe = pkl.load(open('pipe.pkl','rb'))

# %%
# Assume user input
# Pclass | Gender | Age | SibSp | Parch | Fare | Embarked

test_input = np.array([2, 'female', 21.0, 0, 0, 8.0500, 'C'], dtype=object).reshape(1,7)

# %%
pipe.predict(test_input)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([1])
